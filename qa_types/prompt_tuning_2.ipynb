# %% [markdown]
# # QA Prompt Tuning
#
# 所有要改的东西都在下面这一个 cell 里。改完直接跑下面的「运行」cell 看效果。

# %%
import os, sys, json, re
sys.path.append(os.path.dirname(os.getcwd()))

from openai import OpenAI
from config import API_BASE, API_KEY, MODEL

client = OpenAI(base_url=API_BASE, api_key=API_KEY, timeout=600.0)

# %% [markdown]
# ---
# ## 配置区（改这里）

# %%
# ============================================================
# 一、目标书籍（调 prompt 时一次只跑一本）
# ============================================================
BOOKS = ["Far from the Madding Crowd.cleaned.txt"]  # 调 prompt 用第一本，批量生产时跑全部


# ============================================================
# 二、总结提示词（控制 LLM 如何写 section summary）
# ============================================================
SUMMARY_PROMPT = """You are a literary analyst. For the given book section, write a concise summary covering:
- Key events and plot developments
- Character introductions, interactions, and relationships
- How each character is referred to — full names, titles, nicknames, surname-only references, pseudonyms

Pay special attention to name variations: if a character is called by different names in this section (e.g., "Mr. Boldwood" and "William Boldwood"), note this explicitly — it will be crucial for alias extraction later.

Output ONLY the summary text. Do NOT extract triples or add any other sections."""


# ============================================================
# 三、出题提示词（控制 LLM 生成什么类型的 QA）
# ============================================================
QA_PROMPT = """You are given section summaries of one or more books.
Based on the summaries, generate 3-5 high-quality question-answer pairs about the book content.
Each QA pair should test deep understanding of characters, relationships, events, and plot.

Requirements:
- Questions should be diverse: some about characters, some about events, some about relationships.
- Answers should be accurate and cite specific details from the summaries.
- CRITICAL: For each factual claim in each answer, cite the source section number(s) in brackets:
  [3] or [5][6][7]. Every distinct fact must have a citation.
  Do NOT use range notation like [5-7]; write [5][6][7] instead.
- Avoid yes/no questions; prefer open-ended questions requiring reasoning.
- Questions must NOT contain section numbers (e.g., "in Section X").

Output format — a JSON array of objects:
[
    {
        "book": "<book title>",
        "question": "<question>",
        "answer": "<answer with [N] citations>"
    },
    ...
]

Return ONLY the JSON array, no other text."""


# ============================================================
# 四、其他参数（和 question_types.py 对齐）
# ============================================================
TEMPERATURE = 0.3
NUM_QUESTIONS = "3-5"

# %% [markdown]
# ---
# ## 运行（不要改这里）

# %%
# ════════════════════════════════════════════════════════════════
# 运行（不要改这里）
# ════════════════════════════════════════════════════════════════

import importlib
import pipeline as _pl
importlib.reload(_pl)

from pipeline import process_books
from config import WORKERS

result = process_books(
    selected_names=BOOKS,
    question=None,
    question_type=None,
    override_prompts={
        "label": "notebook调试",
        "summary_prompt": SUMMARY_PROMPT,
        "qa_prompt": QA_PROMPT,
    },
)

print(result["answer_with_evidence"])
# Out:
#   Using override prompts (notebook调试).
#   [Far from the Madding Crowd.cleaned.txt] 256 windows
#   Processing 256 windows (8 workers)...
#   [8/256] done
#   [3/256] done
#   [1/256] done
#   [4/256] done
#   [2/256] done
#   [7/256] done
#   [6/256] done
#   [5/256] done
#   [9/256] done
#   [11/256] done
#   [12/256] done
#   [14/256] done
#   [13/256] done
#   [16/256] done
#   [17/256] done
#   [18/256] done
#   [15/256] done
#   [21/256] done
#   [10/256] done
#   [19/256] done
#   [20/256] done
#   [27/256] done
#   [23/256] done
#   [26/256] done
#   [22/256] done
#   [25/256] done
#   [24/256] done
#   [Retry 1/5] API call failed, waiting 2s: Error code: 400 - {'error': {'message': '<400> InternalError.Algo.DataInspectionFailed: Input text data may contain inappropriate content. (request id: 2026070814261758809746732148794)', 'type': 'v_api_biz_error', 'param': '', 'code': 'data_inspection_failed'}}
#   [28/256] done
#   [29/256] done
#   [Retry 2/5] API call failed, waiting 4s: Error code: 400 - {'error': {'message': '<400> InternalError.Algo.DataInspectionFailed: Input text data may contain inappropriate content. (request id: 2026070814262054486841820055349)', 'type': 'v_api_biz_error', 'param': '', 'code': 'data_inspection_failed'}}
#   [Retry 3/5] API call failed, waiting 6s: Error code: 400 - {'error': {'message': '<400> InternalError.Algo.DataInspectionFailed: Input text data may contain inappropriate content. (request id: 2026070814262569453910165987829)', 'type': 'v_api_biz_error', 'param': '', 'code': 'data_inspection_failed'}}
#   [Retry 4/5] API call failed, waiting 8s: Error code: 400 - {'error': {'message': '<400> InternalError.Algo.DataInspectionFailed: Input text data may contain inappropriate content. (request id: 2026070814263326957113194149114)', 'type': 'v_api_biz_error', 'param': '', 'code': 'data_inspection_failed'}}
#   [30/256] done
#   [33/256] done
#   [Retry 5/5] API call failed, waiting 10s: Error code: 400 - {'error': {'message': '<400> InternalError.Algo.DataInspectionFailed: Input text data may contain inappropriate content. (request id: 2026070814264275758542743037755)', 'type': 'v_api_biz_error', 'param': '', 'code': 'data_inspection_failed'}}
#   [31/256] done
#   [36/256] done
#   [37/256] done
#   [35/256] done
#   [Retry 1/5] API call failed, waiting 2s: Error code: 400 - {'error': {'message': '<400> InternalError.Algo.DataInspectionFailed: Input text data may contain inappropriate content. (request id: 2026070814265945177669028188569)', 'type': 'v_api_biz_error', 'param': '', 'code': 'data_inspection_failed'}}
#   [32/256] done
#   [Retry 2/5] API call failed, waiting 4s: Error code: 400 - {'error': {'message': '<400> InternalError.Algo.DataInspectionFailed: Input text data may contain inappropriate content. (request id: 202607081427035046576468428779)', 'type': 'v_api_biz_error', 'param': '', 'code': 'data_inspection_failed'}}
#   [Retry 3/5] API call failed, waiting 6s: Error code: 400 - {'error': {'message': '<400> InternalError.Algo.DataInspectionFailed: Input text data may contain inappropriate content. (request id: 2026070814270848005528932897291)', 'type': 'v_api_biz_error', 'param': '', 'code': 'data_inspection_failed'}}
#   [42/256] done
#   [39/256] done
#   [Retry 4/5] API call failed, waiting 8s: Error code: 400 - {'error': {'message': '<400> InternalError.Algo.DataInspectionFailed: Input text data may contain inappropriate content. (request id: 2026070814271612840526122507598)', 'type': 'v_api_biz_error', 'param': '', 'code': 'data_inspection_failed'}}
#   [43/256] done
#   [40/256] done
#   [38/256] done
#   [Retry 5/5] API call failed, waiting 10s: Error code: 400 - {'error': {'message': '<400> InternalError.Algo.DataInspectionFailed: Input text data may contain inappropriate content. (request id: 2026070814272567479079454823473)', 'type': 'v_api_biz_error', 'param': '', 'code': 'data_inspection_failed'}}
#   [44/256] done
#   [41/256] done
#   [Retry 1/5] API call failed, waiting 2s: Error code: 400 - {'error': {'message': '<400> InternalError.Algo.DataInspectionFailed: Input text data may contain inappropriate content. (request id: 2026070814274274026105804382832)', 'type': 'v_api_biz_error', 'param': '', 'code': 'data_inspection_failed'}}
#   [Retry 2/5] API call failed, waiting 4s: Error code: 400 - {'error': {'message': '<400> InternalError.Algo.DataInspectionFailed: Input text data may contain inappropriate content. (request id: 2026070814274619359339398538279)', 'type': 'v_api_biz_error', 'param': '', 'code': 'data_inspection_failed'}}
#   [47/256] done
#   [45/256] done
#   [46/256] done
#   [Retry 3/5] API call failed, waiting 6s: Error code: 400 - {'error': {'message': '<400> InternalError.Algo.DataInspectionFailed: Input text data may contain inappropriate content. (request id: 2026070814275128486139355072710)', 'type': 'v_api_biz_error', 'param': '', 'code': 'data_inspection_failed'}}
#   [Retry 4/5] API call failed, waiting 8s: Error code: 400 - {'error': {'message': '<400> InternalError.Algo.DataInspectionFailed: Input text data may contain inappropriate content. (request id: 2026070814275890838820487954844)', 'type': 'v_api_biz_error', 'param': '', 'code': 'data_inspection_failed'}}
#   [48/256] done
#   [Retry 5/5] API call failed, waiting 10s: Error code: 400 - {'error': {'message': '<400> InternalError.Algo.DataInspectionFailed: Input text data may contain inappropriate content. (request id: 2026070814280842124787773294499)', 'type': 'v_api_biz_error', 'param': '', 'code': 'data_inspection_failed'}}
#   [50/256] done
#   [49/256] done
#   [53/256] done
#   [52/256] done
#   [Warn] summarize_one_adversarial failed after 3 attempts: API call failed after 6 attempts: Error code: 400 - {'error': {'message': '<400> InternalError.Algo.DataInspectionFailed: Input text data may contain inappropriate content. (request id: 2026070814281981081990936698564)', 'type': 'v_api_biz_error', 'param': '', 'code': 'data_inspection_failed'}}
#   [34/256] done
#   [51/256] done
#   [54/256] done
#   [55/256] done
#   [59/256] done
#   [57/256] done
#   [58/256] done
#   [60/256] done
#   [56/256] done
#   [63/256] done
#   [62/256] done
#   [61/256] done
#   [65/256] done
#   [64/256] done
#   [66/256] done
#   [68/256] done
#   [70/256] done
#   [69/256] done
#   [67/256] done
#   [71/256] done
#   [75/256] done
#   [73/256] done
#   [74/256] done
#   [77/256] done
#   [72/256] done
#   [78/256] done
#   [76/256] done
#   [81/256] done
#   [82/256] done
#   [83/256] done
#   [79/256] done
#   [80/256] done
#   [85/256] done
#   [84/256] done
#   [86/256] done
#   [91/256] done
#   [87/256] done
#   [88/256] done
#   [89/256] done
#   [90/256] done
#   [92/256] done
#   [93/256] done
#   [94/256] done
#   [100/256] done
#   [95/256] done
#   [97/256] done
#   [101/256] done
#   [98/256] done
#   [96/256] done
#   [99/256] done
#   [103/256] done
#   [102/256] done
#   [108/256] done
#   [104/256] done
#   [107/256] done
#   [105/256] done
#   [106/256] done
#   [109/256] done
#   [110/256] done
#   [114/256] done
#   [111/256] done
#   [115/256] done
#   [117/256] done
#   [113/256] done
#   [116/256] done
#   [118/256] done
#   [119/256] done
#   [112/256] done
#   [120/256] done
#   [122/256] done
#   [124/256] done
#   [121/256] done
#   [127/256] done
#   [123/256] done
#   [126/256] done
#   [125/256] done
#   [130/256] done
#   [128/256] done
#   [134/256] done
#   [129/256] done
#   [133/256] done
#   [131/256] done
#   [137/256] done
#   [136/256] done
#   [135/256] done
#   [132/256] done
#   [138/256] done
#   [143/256] done
#   [139/256] done
#   [140/256] done
#   [144/256] done
#   [141/256] done
#   [148/256] done
#   [147/256] done
#   [142/256] done
#   [146/256] done
#   [145/256] done
#   [149/256] done
#   [154/256] done
#   [152/256] done
#   [156/256] done
#   [150/256] done
#   [151/256] done
#   [153/256] done
#   [155/256] done
#   [157/256] done
#   [158/256] done
#   [160/256] done
#   [159/256] done
#   [163/256] done
#   [162/256] done
#   [161/256] done
#   [166/256] done
#   [167/256] done
#   [164/256] done
#   [168/256] done
#   [165/256] done
#   [169/256] done
#   [171/256] done
#   [172/256] done
#   [170/256] done
#   [173/256] done
#   [174/256] done
#   [177/256] done
#   [176/256] done
#   [178/256] done
#   [181/256] done
#   [175/256] done
#   [179/256] done
#   [184/256] done
#   [187/256] done
#   [186/256] done
#   [182/256] done
#   [180/256] done
#   [188/256] done
#   [185/256] done
#   [189/256] done
#   [183/256] done
#   [191/256] done
#   [194/256] done
#   [193/256] done
#   [192/256] done
#   [190/256] done
#   [197/256] done
#   [196/256] done
#   [200/256] done
#   [198/256] done
#   [201/256] done
#   [199/256] done
#   [195/256] done
#   [202/256] done
#   [204/256] done
#   [203/256] done
#   [205/256] done
#   [208/256] done
#   [207/256] done
#   [209/256] done
#   [206/256] done
#   [213/256] done
#   [210/256] done
#   [212/256] done
#   [216/256] done
#   [214/256] done
#   [211/256] done
#   [218/256] done
#   [215/256] done
#   [220/256] done
#   [219/256] done
#   [217/256] done
#   [221/256] done
#   [222/256] done
#   [225/256] done
#   [224/256] done
#   [226/256] done
#   [223/256] done
#   [228/256] done
#   [229/256] done
#   [232/256] done
#   [227/256] done
#   [233/256] done
#   [230/256] done
#   [234/256] done
#   [240/256] done
#   [231/256] done
#   [238/256] done
#   [236/256] done
#   [237/256] done
#   [239/256] done
#   [241/256] done
#   [235/256] done
#   [248/256] done
#   [242/256] done
#   [245/256] done
#   [247/256] done
#   [246/256] done
#   [243/256] done
#   [244/256] done
#   [249/256] done
#   [250/256] done
#   [251/256] done
#   [252/256] done
#   [256/256] done
#   [254/256] done
#   [255/256] done
#   [253/256] done
#
#   All 256 windows summarized (0 triples after post-processing).
#   Generating QA pairs from summaries (notebook调试)...
#
#   Chunk registry saved: d:\code\北大\model_train\output\chunk_registry_20260708_144217.json
#   Verifying evidence from original text...
#   [Evidence] 验证完成, 27 条证据
#   [Evidence] 软校验: 27/27 条正常
#   Result saved: d:\code\北大\model_train\output\result_notebook调试_20260708_144351.json
# [
#   {
#     "book": "Far from the Madding Crowd",
#     "question": "How does Gabriel Oak's perception of Bathsheba Everdene evolve from their initial meeting to his eventual proposal?",
#     "answer": "Initially, Gabriel views Bathsheba as vain when he observes her admiring herself in a hand-glass while traveling in a waggon. Later, after she saves him from suffocation in the cowshed, his affection deepens significantly. Although he eventually proposes marriage and is rejected because she values her independence over having a husband constantly present, their relationship culminates in marriage after years of separation and tragedy involving other suitors.",
#     "evidence": [
#       "\"a small swing looking-glass was disclosed, in which she proceeded to survey herself attentively.\"",
#       "\"There was no necessity whatever for her looking in the glass.\"",
#       "\"It is a wonder you were not suffocated in this hut of yours.\"",
#       "\"I believe you saved my life, Miss\"",
#       "\"No; 'tis no use,\" she said. \"I don't want to marry you.\"",
#       "\"Because I don't love you.\"",
#       "\"I want somebody to tame me; I am too independent\"",
#       "\"In the church were Tall, Liddy, and the parson, and in a remarkably short space of time the deed was done.\""
#     ]
#   },
#   {
#     "book": "Far from the Madding Crowd",
#     "question": "What sequence of events leads to Gabriel Oak losing his entire flock of sheep?",
#     "answer": "Gabriel's younger dog, George's son, drives the ewes over a rotten railing after eating a dead lamb left by Gabriel before he slept. This causes two hundred ewes to fall into a chalk-pit where they die, destroying his life savings since the sheep were uninsured. Consequently, Gabriel becomes destitute and must seek employment as a hired shepherd rather than remaining an independent farmer.",
#     "evidence": [
#       "\"left the two dogs on the hill eating a dead lamb\"",
#       "\"collected all the ewes into a corner, driven the timid creatures through the hedge, across the upper field, and by main force of worrying had given them momentum enough to break down a portion of the rotten railing, and so hurled them over the edge.\"",
#       "\"The ewes lay dead and dying at its foot—a heap of two hundred mangled carcasses\"",
#       "\"The sheep were not insured. All the savings of a frugal life had been dispersed at a blow\"",
#       "\"All the farmers seemed to be wanting shepherds. Sheep-tending was Gabriel's speciality.\"",
#       "\"stood on the kerb of the pavement, as a shepherd, crook in hand.\""
#     ]
#   },
#   {
#     "book": "Far from the Madding Crowd",
#     "question": "How does the Valentine card incident alter Farmer Boldwood's behavior toward Bathsheba Everdene?",
#     "answer": "Bathsheba sends a valentine stamped 'M ARRY M E' which Boldwood misreads as a solemn proposition rather than a thoughtless act. He interprets this as proof of her affection and resolves to pursue her despite being a confirmed bachelor previously. His obsession intensifies until he shoots Troy at Christmas party upon discovering Troy is alive, leading to his surrender at the gaol.",
#     "evidence": [
#       "\"Liddy looked at the words of the seal, and read—'M ARRY M E.'\"",
#       "\"So very idly and unreflectingly was this deed done.\"",
#       "\"I come to make you an offer of marriage.\"",
#       "\"I may have been called a confirmed bachelor, and I was a confirmed bachelor.\"",
#       "\"He had turned quickly, taken one of the guns, cocked it, and at once discharged it at Troy.\""
#     ]
#   },
#   {
#     "book": "Far from the Madding Crowd",
#     "question": "Why does Sergeant Troy return to Weatherbury disguised as a circus performer instead of revealing himself immediately?",
#     "answer": "Troy returns to Weatherbury after losing his clothes at sea and working passage to the United States as a Professor of Gymnastics. He delays returning to his wife Bathsheba due to shame and fear of her resentment regarding his past actions and financial dependence. To avoid detection while hiding from creditors and his wife, he joins a travelling circus and performs under the guise of Turpin.",
#     "evidence": [
#       "\"He ultimately worked his passage to the United States, where he made a precarious living in various towns as Professor of Gymnastics, Sword Exercise, Fencing, and Pugilism.\"",
#       "\"how could he endure existence with a spirited wife to whom at first entering he would be beholden for food and lodging?\"",
#       "\"Why, there's a blackguard creditor in the tent I don't want to see, who'll discover me and nab me as sure as Satan if I open my mouth.\"",
#       "\"although his disguise effectually concealed his personality\""
#     ]
#   },
#   {
#     "book": "Far from the Madding Crowd",
#     "question": "What circumstances lead to the final union between Gabriel Oak and Bathsheba Everdene?",
#     "answer": "After Boldwood is sentenced to confinement during Her Majesty's pleasure following his insanity trial, Gabriel offers to manage the farm and marry Bathsheba once he secures funds. Despite initial misunderstandings where Gabriel appears to reject her, he clarifies his intention to acquire Little Weatherbury Farm to support their future together. They ultimately wed in a quiet ceremony attended by Liddy and the parson, solidifying their bond after years of turmoil.",
#     "evidence": [
#       "\"'Tis confinement during Her Majesty's pleasure.\"",
#       "\"I have arranged for Little Weatherbury Farm and shall have it in my own hands at Lady-day.\"",
#       "\"Marrying of 'ee, in plain British.\"",
#       "\"In the church were Tall, Liddy, and the parson, and in a remarkably short space of time the deed was done.\""
#     ]
#   }
# ]

# %% [markdown]
# ---
# ## 满意后抄回 question_types.py
#
# 把上面「配置区」的 `SUMMARY_PROMPT` 和 `QA_PROMPT` 内容复制到 `question_types.py` 的对应条目。
